# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train_raw = pd.read_csv('development_dataset.csv')

# %%
train_raw.head()
# Out:
#    VAR1        VAR2      VAR3        VAR4        VAR5      VAR6      VAR7  \
# 0     1  828.235294  0.138889  321.428571  625.911006  1.818182  1.081550
# 1     2  911.764706  0.027778         NaN  611.574748  8.181818  1.344479
# 2     3  962.352941  0.833333   35.714286  615.825381  8.181818  0.720796
# 3     4  892.941177       NaN         NaN  638.076431  9.090909  0.820218
# 4     5  914.117647  0.083333         NaN  626.514988  5.181818  1.372928
#
#          VAR8       VAR9      VAR10  ...       VAR12  VAR13  VAR14 VAR15  \
# 0  198.113469        NaN  58.632548  ...  100.083403    1.0      1   1.0
# 1  198.600020  22.086661        NaN  ...   15.012510    NaN      1   NaN
# 2  197.267767        NaN  58.632548  ...  210.175146   10.0      1  10.0
# 3  197.355744   4.363431  58.632548  ...         NaN    NaN      1   NaN
# 4  198.790477  85.938202  58.632548  ...  210.175146    NaN      .   NaN
#
#       VAR16  VAR17  VAR18  VAR19       VAR20   VAR21
# 0  1.540594    NaN      1      0  100.104991     Low
# 1  1.614613    NaN      0      1  146.654045    High
# 2  1.044599    NaN      0      0   98.249570  Medium
# 3  1.145729    NaN      1      0  140.862306     Low
# 4  1.558341    NaN      1      0  101.268503    High
#
# [5 rows x 21 columns]

# %%
col_names = [ 'ID','FICO','Business Revenue','TSR','Last 6M Avg Util','Income','Last 6M Avg Remit','Last 6M Avg Bal','Internal Revolve','Lending AR% in last 6M',
'ExternalBalance',
'Months in Business',
'preferred_spend_line',
'total_cards',
'preferred_bal_line',
'preavgremit1_3_all',
'External_rev_rate',
'Supplementary Cards',
'isChargeCust',
'CMV',
'Assigned Line']

# %%
train_raw.columns = col_names

# %%
print(train_raw.describe())
# Out:
#                  ID          FICO  Business Revenue           TSR  \
# count  34000.000000  33039.000000      30615.000000  21506.000000
# mean   17000.500000    917.391603          1.119596    248.076201
# std     9815.098913     50.222389         12.714724    241.167723
# min        1.000000    730.588235          0.001333     18.928571
# 25%     8500.750000    882.352941          0.083333     71.428571
# 50%    17000.500000    924.705882          0.166667    142.857143
# 75%    25500.250000    956.470588          0.555556    357.142857
# max    34000.000000   1000.000000       1000.000000   1000.000000
#
#        Last 6M Avg Util        Income  Last 6M Avg Remit  Last 6M Avg Bal  \
# count      33999.000000  30505.000000       33165.000000     33165.000000
# mean         631.571391     15.290028           2.055295       200.007169
# std           30.863288     29.123815           8.960891        11.282223
# min          347.053355      0.005000           0.353228         0.000000
# 25%          611.691167      6.636364           0.691201       197.196716
# 50%          619.802909     10.000000           0.998093       197.912501
# 75%          637.450565     18.181818           1.735250       199.687427
# max         1000.000000    909.090818         681.582083      1000.000000
#
#        Internal Revolve  Lending AR% in last 6M  ExternalBalance  \
# count      18183.000000            29450.000000     26435.000000
# mean          53.988554               56.497320         5.429062
# std           84.573655                6.861058        11.433905
# min            0.004278               13.028620         0.000693
# 25%            8.784613               57.458373         0.638239
# 50%           22.086661               58.632548         2.098360
# 75%           58.559811               58.632548         6.043179
# max          993.061289             1000.000000       824.334457
#
#        Months in Business  preferred_spend_line  preferred_bal_line  \
# count        23498.000000          25478.000000        25976.000000
# mean           117.283667             11.679589           12.453257
# std            120.628594             11.063966           12.084965
# min              0.834028              0.082667            0.133333
# 25%             15.012510              5.666667            6.666667
# 50%             80.066722             10.000000           10.000000
# 75%            193.494579             15.333333           16.400000
# max           1000.000000            775.000000          775.000000
#
#        preavgremit1_3_all  External_rev_rate  Supplementary Cards  \
# count        33134.000000       11806.000000         34000.000000
# mean             2.092006         821.281092             0.400029
# std              8.051804         262.338240             0.684850
# min              0.959315           0.130000             0.000000
# 25%              1.040125         732.662500             0.000000
# 50%              1.262747         965.345000             0.000000
# 75%              1.827486        1000.000000             1.000000
# max           1000.000000        1000.000000            14.000000
#
#        isChargeCust           CMV
# count  34000.000000  34000.000000
# mean       0.298059    161.355950
# std        0.457412    123.231136
# min        0.000000      0.000000
# 25%        0.000000    104.385542
# 50%        0.000000    117.493115
# 75%        1.000000    159.446213
# max        1.000000   1000.000000

# %%
train_raw.shape
# Out:
# (34000, 21)

# %%
train_raw.head()
# Out:
#    ID        FICO  Business Revenue         TSR  Last 6M Avg Util    Income  \
# 0   1  828.235294          0.138889  321.428571        625.911006  1.818182
# 1   2  911.764706          0.027778         NaN        611.574748  8.181818
# 2   3  962.352941          0.833333   35.714286        615.825381  8.181818
# 3   4  892.941177               NaN         NaN        638.076431  9.090909
# 4   5  914.117647          0.083333         NaN        626.514988  5.181818
#
#    Last 6M Avg Remit  Last 6M Avg Bal  Internal Revolve  \
# 0           1.081550       198.113469               NaN
# 1           1.344479       198.600020         22.086661
# 2           0.720796       197.267767               NaN
# 3           0.820218       197.355744          4.363431
# 4           1.372928       198.790477         85.938202
#
#    Lending AR% in last 6M  ...  Months in Business  preferred_spend_line  \
# 0               58.632548  ...          100.083403                   1.0
# 1                     NaN  ...           15.012510                   NaN
# 2               58.632548  ...          210.175146                  10.0
# 3               58.632548  ...                 NaN                   NaN
# 4               58.632548  ...          210.175146                   NaN
#
#    total_cards preferred_bal_line  preavgremit1_3_all  External_rev_rate  \
# 0            1                1.0            1.540594                NaN
# 1            1                NaN            1.614613                NaN
# 2            1               10.0            1.044599                NaN
# 3            1                NaN            1.145729                NaN
# 4            .                NaN            1.558341                NaN
#
#    Supplementary Cards  isChargeCust         CMV  Assigned Line
# 0                    1             0  100.104991            Low
# 1                    0             1  146.654045           High
# 2                    0             0   98.249570         Medium
# 3                    1             0  140.862306            Low
# 4                    1             0  101.268503           High
#
# [5 rows x 21 columns]

# %%
print(train_raw.groupby('Assigned Line').size())
# Out:
# Assigned Line
# High       3747
# Low       12081
# Medium    18172
# dtype: int64

# %%
#Univariate Plots

sns.set(rc={'figure.figsize':(20,11)})

# box and whisker plots
train_raw[['FICO','Business Revenue','TSR','Last 6M Avg Util']].plot(kind='box', subplots=True,layout=(2,2), sharex=False, sharey=False)
# Out:
# FICO                   AxesSubplot(0.125,0.536818;0.352273x0.343182)
# Business Revenue    AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# TSR                       AxesSubplot(0.125,0.125;0.352273x0.343182)
# Last 6M Avg Util       AxesSubplot(0.547727,0.125;0.352273x0.343182)
# dtype: object

# %%
# box and whisker plots
train_raw[['Income','Last 6M Avg Remit','Last 6M Avg Bal','Internal Revolve']].plot(kind='box', subplots=True,layout=(2,2), sharex=False, sharey=False)
# Out:
# Income                  AxesSubplot(0.125,0.536818;0.352273x0.343182)
# Last 6M Avg Remit    AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# Last 6M Avg Bal            AxesSubplot(0.125,0.125;0.352273x0.343182)
# Internal Revolve        AxesSubplot(0.547727,0.125;0.352273x0.343182)
# dtype: object

# %%
# box and whisker plots
train_raw[['Lending AR% in last 6M',
'ExternalBalance',
'Months in Business',
'preferred_spend_line']].plot(kind='box', subplots=True,layout=(2,2), sharex=False, sharey=False)
# Out:
# Lending AR% in last 6M       AxesSubplot(0.125,0.536818;0.352273x0.343182)
# ExternalBalance           AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# Months in Business              AxesSubplot(0.125,0.125;0.352273x0.343182)
# preferred_spend_line         AxesSubplot(0.547727,0.125;0.352273x0.343182)
# dtype: object

# %%
# box and whisker plots
train_raw[['total_cards',
'preferred_bal_line',
'preavgremit1_3_all',
'External_rev_rate']].plot(kind='box', subplots=True,layout=(2,2), sharex=False, sharey=False)
# Out:
# preferred_bal_line       AxesSubplot(0.125,0.536818;0.352273x0.343182)
# preavgremit1_3_all    AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# External_rev_rate           AxesSubplot(0.125,0.125;0.352273x0.343182)
# dtype: object

# %%
sns.countplot(train_raw['Supplementary Cards'])

# %%
train_raw.columns
# Out:
# Index(['ID', 'FICO', 'Business Revenue', 'TSR', 'Last 6M Avg Util', 'Income',
#        'Last 6M Avg Remit', 'Last 6M Avg Bal', 'Internal Revolve',
#        'Lending AR% in last 6M', 'ExternalBalance', 'Months in Business',
#        'preferred_spend_line', 'total_cards', 'preferred_bal_line',
#        'preavgremit1_3_all', 'External_rev_rate', 'Supplementary Cards',
#        'isChargeCust', 'CMV', 'Assigned Line'],
#       dtype='object')

# %%
sns.countplot(train_raw['isChargeCust'])

# %%
sns.set(rc={'figure.figsize':(8,8)})
train_raw[['CMV']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e28027278>]],
#       dtype=object)

# %%
train_raw[['preferred_bal_line' ,'Income','preferred_spend_line']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e21a14668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e219eb1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1e21995b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1e2194f550>]],
#       dtype=object)

# %%
train_1 = train_raw.dropna()

# %%
train_1.shape
# Out:
# (2059, 21)

# %%
sns.heatmap(train_raw.isnull(), cbar=False)

# %%
#Removing TSR ,Internal Revolve , External_rev_rate
train_2 = train_raw.drop(['TSR','Internal Revolve','External_rev_rate'], axis=1)

# %%
train_2
# Out:
#           ID        FICO  Business Revenue  Last 6M Avg Util     Income  \
# 0          1  828.235294          0.138889        625.911006   1.818182
# 1          2  911.764706          0.027778        611.574748   8.181818
# 2          3  962.352941          0.833333        615.825381   8.181818
# 3          4  892.941177               NaN        638.076431   9.090909
# 4          5  914.117647          0.083333        626.514988   5.181818
# ...      ...         ...               ...               ...        ...
# 33995  33996  996.470588          0.833333        611.574748   9.090909
# 33996  33997  885.882353               NaN        617.448254  22.727273
# 33997  33998  976.470588          0.166667        621.613105  18.181818
# 33998  33999  785.882353          0.177233        682.762351        NaN
# 33999  34000  917.647059          0.138889        650.416923  11.818182
#
#        Last 6M Avg Remit  Last 6M Avg Bal  Lending AR% in last 6M  \
# 0               1.081550       198.113469               58.632548
# 1               1.344479       198.600020                     NaN
# 2               0.720796       197.267767               58.632548
# 3               0.820218       197.355744               58.632548
# 4               1.372928       198.790477               58.632548
# ...                  ...              ...                     ...
# 33995           2.040273       199.590730                     NaN
# 33996           0.943654       197.743579               58.632548
# 33997           0.968569       197.437342               58.632548
# 33998           0.623798       198.254389               58.632548
# 33999           2.640652       201.389811               58.632548
#
#        ExternalBalance  Months in Business  preferred_spend_line total_cards  \
# 0             0.279273          100.083403              1.000000           1
# 1                  NaN           15.012510                   NaN           1
# 2             0.453212          210.175146             10.000000           1
# 3                  NaN                 NaN                   NaN           1
# 4                  NaN          210.175146                   NaN           .
# ...                ...                 ...                   ...         ...
# 33995         1.837104          250.208507             13.333333           1
# 33996              NaN            5.004170                   NaN           1
# 33997         1.172531          130.108424              2.000000           1
# 33998         8.072586           18.348624             11.866667           1
# 33999        29.354858          150.125104              5.400000           1
#
#        preferred_bal_line  preavgremit1_3_all  Supplementary Cards  \
# 0                1.000000            1.540594                    1
# 1                     NaN            1.614613                    0
# 2               10.000000            1.044599                    0
# 3                     NaN            1.145729                    1
# 4                     NaN            1.558341                    1
# ...                   ...                 ...                  ...
# 33995           13.333333            1.913514                    1
# 33996                 NaN            1.014169                    0
# 33997           12.666667            1.228365                    0
# 33998           11.866667            0.976599                    0
# 33999           10.000000            2.319554                    1
#
#        isChargeCust         CMV Assigned Line
# 0                 0  100.104991           Low
# 1                 1  146.654045          High
# 2                 0   98.249570        Medium
# 3                 0  140.862306           Low
# 4                 0  101.268503          High
# ...             ...         ...           ...
# 33995             1  155.080895           Low
# 33996             0  162.972461        Medium
# 33997             0  108.767642           Low
# 33998             0  101.471601           Low
# 33999             0   52.588640          High
#
# [34000 rows x 18 columns]

# %%
sns.heatmap(train_2.corr())

# %%
sns.heatmap(train_2.isnull(), cbar=False)

# %%
train_2.describe()
# Out:
#                  ID          FICO  Business Revenue  Last 6M Avg Util  \
# count  34000.000000  33039.000000      30615.000000      33999.000000
# mean   17000.500000    917.391603          1.119596        631.571391
# std     9815.098913     50.222389         12.714724         30.863288
# min        1.000000    730.588235          0.001333        347.053355
# 25%     8500.750000    882.352941          0.083333        611.691167
# 50%    17000.500000    924.705882          0.166667        619.802909
# 75%    25500.250000    956.470588          0.555556        637.450565
# max    34000.000000   1000.000000       1000.000000       1000.000000
#
#              Income  Last 6M Avg Remit  Last 6M Avg Bal  \
# count  30505.000000       33165.000000     33165.000000
# mean      15.290028           2.055295       200.007169
# std       29.123815           8.960891        11.282223
# min        0.005000           0.353228         0.000000
# 25%        6.636364           0.691201       197.196716
# 50%       10.000000           0.998093       197.912501
# 75%       18.181818           1.735250       199.687427
# max      909.090818         681.582083      1000.000000
#
#        Lending AR% in last 6M  ExternalBalance  Months in Business  \
# count            29450.000000     26435.000000        23498.000000
# mean                56.497320         5.429062          117.283667
# std                  6.861058        11.433905          120.628594
# min                 13.028620         0.000693            0.834028
# 25%                 57.458373         0.638239           15.012510
# 50%                 58.632548         2.098360           80.066722
# 75%                 58.632548         6.043179          193.494579
# max               1000.000000       824.334457         1000.000000
#
#        preferred_spend_line  preferred_bal_line  preavgremit1_3_all  \
# count          25478.000000        25976.000000        33134.000000
# mean              11.679589           12.453257            2.092006
# std               11.063966           12.084965            8.051804
# min                0.082667            0.133333            0.959315
# 25%                5.666667            6.666667            1.040125
# 50%               10.000000           10.000000            1.262747
# 75%               15.333333           16.400000            1.827486
# max              775.000000          775.000000         1000.000000
#
#        Supplementary Cards  isChargeCust           CMV
# count         34000.000000  34000.000000  34000.000000
# mean              0.400029      0.298059    161.355950
# std               0.684850      0.457412    123.231136
# min               0.000000      0.000000      0.000000
# 25%               0.000000      0.000000    104.385542
# 50%               0.000000      0.000000    117.493115
# 75%               1.000000      1.000000    159.446213
# max              14.000000      1.000000   1000.000000

# %%
import scipy
from sklearn.preprocessing import MinMaxScaler

# %%
train_2.head()
# Out:
#    ID        FICO  Business Revenue  Last 6M Avg Util    Income  \
# 0   1  828.235294          0.138889        625.911006  1.818182
# 1   2  911.764706          0.027778        611.574748  8.181818
# 2   3  962.352941          0.833333        615.825381  8.181818
# 3   4  892.941177               NaN        638.076431  9.090909
# 4   5  914.117647          0.083333        626.514988  5.181818
#
#    Last 6M Avg Remit  Last 6M Avg Bal  Lending AR% in last 6M  \
# 0           1.081550       198.113469               58.632548
# 1           1.344479       198.600020                     NaN
# 2           0.720796       197.267767               58.632548
# 3           0.820218       197.355744               58.632548
# 4           1.372928       198.790477               58.632548
#
#    ExternalBalance  Months in Business  preferred_spend_line total_cards  \
# 0         0.279273          100.083403                   1.0           1
# 1              NaN           15.012510                   NaN           1
# 2         0.453212          210.175146                  10.0           1
# 3              NaN                 NaN                   NaN           1
# 4              NaN          210.175146                   NaN           .
#
#    preferred_bal_line  preavgremit1_3_all  Supplementary Cards  isChargeCust  \
# 0                 1.0            1.540594                    1             0
# 1                 NaN            1.614613                    0             1
# 2                10.0            1.044599                    0             0
# 3                 NaN            1.145729                    1             0
# 4                 NaN            1.558341                    1             0
#
#           CMV Assigned Line
# 0  100.104991           Low
# 1  146.654045          High
# 2   98.249570        Medium
# 3  140.862306           Low
# 4  101.268503          High

# %%
train_2_mean = train_2.fillna(train_2.mean())

# %%
k = train_2_mean['Assigned Line'][4:5]
k = 2
k
# Out:
# 2

# %%
myl = []
for i in range(len(train_2_mean['Assigned Line'])):
    if(train_2_mean['Assigned Line'][i] == 'Low'):
        myl.append(0)
    elif(train_2_mean['Assigned Line'][i]=='Medium'):
        myl.append(1)
    else:
        myl.append(2)
train_2_mean['final Line'] = myl

# %%
train_2_mean = train_2_mean.drop('Assigned Line' ,axis=1)

# %%
train_2_mean.head()
# Out:
#    ID        FICO  Business Revenue  Last 6M Avg Util    Income  \
# 0   1  828.235294          0.138889        625.911006  1.818182
# 1   2  911.764706          0.027778        611.574748  8.181818
# 2   3  962.352941          0.833333        615.825381  8.181818
# 3   4  892.941177          1.119596        638.076431  9.090909
# 4   5  914.117647          0.083333        626.514988  5.181818
#
#    Last 6M Avg Remit  Last 6M Avg Bal  Lending AR% in last 6M  \
# 0           1.081550       198.113469               58.632548
# 1           1.344479       198.600020               56.497320
# 2           0.720796       197.267767               58.632548
# 3           0.820218       197.355744               58.632548
# 4           1.372928       198.790477               58.632548
#
#    ExternalBalance  Months in Business  preferred_spend_line total_cards  \
# 0         0.279273          100.083403              1.000000           1
# 1         5.429062           15.012510             11.679589           1
# 2         0.453212          210.175146             10.000000           1
# 3         5.429062          117.283667             11.679589           1
# 4         5.429062          210.175146             11.679589           .
#
#    preferred_bal_line  preavgremit1_3_all  Supplementary Cards  isChargeCust  \
# 0            1.000000            1.540594                    1             0
# 1           12.453257            1.614613                    0             1
# 2           10.000000            1.044599                    0             0
# 3           12.453257            1.145729                    1             0
# 4           12.453257            1.558341                    1             0
#
#           CMV  final Line
# 0  100.104991           0
# 1  146.654045           2
# 2   98.249570           1
# 3  140.862306           0
# 4  101.268503           2

# %%
train_2_mean[train_2_mean['total_cards']=='.'] = 1

# %%
train_2_mean['Assigned Line'] = train_2_mean['final Line']

# %%
train_2_mean = train_2_mean.drop('final Line' ,axis=1)

# %%
train_2_mean = train_2_mean.astype({'total_cards' : 'int64' , 'Assigned Line': 'int64' })

# %%
train_2_mean.dtypes
# Out:
# ID                          int64
# FICO                      float64
# Business Revenue          float64
# Last 6M Avg Util          float64
# Income                    float64
# Last 6M Avg Remit         float64
# Last 6M Avg Bal           float64
# Lending AR% in last 6M    float64
# ExternalBalance           float64
# Months in Business        float64
# preferred_spend_line      float64
# total_cards                 int64
# preferred_bal_line        float64
# preavgremit1_3_all        float64
# Supplementary Cards         int64
# isChargeCust                int64
# CMV                       float64
# Assigned Line               int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
cols_x = ['FICO', 'Business Revenue', 'Last 6M Avg Util', 'Income',
       'Last 6M Avg Remit', 'Last 6M Avg Bal', 'Lending AR% in last 6M',
       'ExternalBalance', 'Months in Business', 'preferred_spend_line',
       'total_cards', 'preferred_bal_line', 'preavgremit1_3_all',
       'Supplementary Cards', 'isChargeCust', 'CMV']
cols_y = ['Assigned Line']

# %%
#train test split

train_x, test_x, train_y, test_y = train_test_split(train_2_mean[cols_x], train_2_mean[cols_y],
                                                        train_size=0.7,random_state=1)

# %%
clf = RandomForestClassifier()

# %%
clf.fit(train_x, train_y)
# Out:
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predictions = clf.predict(test_x)

# %%
# Train and Test Accuracy
print("Train Accuracy :: ", accuracy_score(train_y, clf.predict(train_x)))
print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
# Out:
# Train Accuracy ::  0.9829411764705882
# Test Accuracy  ::  0.5255882352941177

# %%
#tuning n estimators

n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200]

for estimator in n_estimators:
    clf = RandomForestClassifier(n_estimators=estimator)
    clf.fit(train_x, train_y)
    predictions = clf.predict(test_x)
    print(estimator)
    print("\n")
    print("Train Accuracy :: ", accuracy_score(train_y, clf.predict(train_x)))
    print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
    print("\n\n")
# Out:
# 1
#
#
# Train Accuracy ::  0.8001680672268907
# Test Accuracy  ::  0.4562745098039216
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 2
#
#
# Train Accuracy ::  0.8030252100840336
# Test Accuracy  ::  0.46705882352941175
#
#
#
# 4
#
#
# Train Accuracy ::  0.9145798319327731
# Test Accuracy  ::  0.492156862745098
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 8
#
#
# Train Accuracy ::  0.9753361344537815
# Test Accuracy  ::  0.5218627450980392
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 16
#
#
# Train Accuracy ::  0.9958403361344538
# Test Accuracy  ::  0.5412745098039216
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 32
#
#
# Train Accuracy ::  0.9996638655462184
# Test Accuracy  ::  0.5524509803921569
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 64
#
#
# Train Accuracy ::  1.0
# Test Accuracy  ::  0.5574509803921569
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 100
#
#
# Train Accuracy ::  1.0
# Test Accuracy  ::  0.5598039215686275
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 200
#
#
# Train Accuracy ::  1.0
# Test Accuracy  ::  0.5637254901960784

# %%
sns.heatmap(train_2_mean.corr())

# %%
listofcols_highcorr = [['Last 6M Avg Remit','preavgremit1_3_all']]

# %%
col_names_eval = [ 'ID','FICO','Business Revenue','TSR','Last 6M Avg Util','Income','Last 6M Avg Remit','Last 6M Avg Bal','Internal Revolve','Lending AR% in last 6M',
'ExternalBalance',
'Months in Business',
'preferred_spend_line',
'total_cards',
'preferred_bal_line',
'preavgremit1_3_all',
'External_rev_rate',
'Supplementary Cards',
'isChargeCust',
'CMV'
]

# %%
evaluation_raw = pd.read_csv('leaderboard_dataset.csv')
evaluation_raw.columns = col_names_eval
#Removing TSR ,Internal Revolve , External_rev_rate
eval_2 = evaluation_raw.drop(['TSR','Internal Revolve','External_rev_rate','ID'], axis=1)
eval_2_mean = eval_2.fillna(eval_2.mean())
# myl = []
# for i in range(len(eval_2_mean['Assigned Line'])):
#     if(eval_2_mean['Assigned Line'][i] == 'Low'):
#         myl.append(0)
#     elif(eval_2_mean['Assigned Line'][i]=='Medium'):
#         myl.append(1)
#     else:
#         myl.append(2)
# eval_2_mean['final Line'] = myl
# eval_2_mean = eval_2_mean.drop('Assigned Line' ,axis=1)
eval_2_mean[eval_2_mean['total_cards']=='.'] = 1
# eval_2_mean['Assigned Line'] = eval_2_mean['final Line']
# eval_2_mean = eval_2_mean.drop('final Line' ,axis=1)
eval_2_mean = eval_2_mean.astype({'total_cards' : 'int64'})

# %%
train_2_mean_rem = train_2_mean.drop(['Last 6M Avg Remit','ID'],axis=1)
eval_2_mean_rem = eval_2_mean.drop(['Last 6M Avg Remit'],axis=1)

# %%
eval_2_mean_rem.columns
# Out:
# Index(['FICO', 'Business Revenue', 'Last 6M Avg Util', 'Income',
#        'Last 6M Avg Bal', 'Lending AR% in last 6M', 'ExternalBalance',
#        'Months in Business', 'preferred_spend_line', 'total_cards',
#        'preferred_bal_line', 'preavgremit1_3_all', 'Supplementary Cards',
#        'isChargeCust', 'CMV'],
#       dtype='object')

# %%
eval_2_mean_rem.head()
# Out:
#          FICO  Business Revenue  Last 6M Avg Util     Income  Last 6M Avg Bal  \
# 0  878.823529          0.833333        620.835806   5.181818       197.500187
# 1  891.764706          0.138889        614.092215   3.909091       197.016843
# 2  955.294118          0.055556        611.574748   6.363636       197.660051
# 3  831.764706          0.111111        617.740617   6.545455       200.526288
# 4  957.647059          0.166667        623.426802  15.185077       197.151458
#
#    Lending AR% in last 6M  ExternalBalance  Months in Business  \
# 0               58.632548         9.433609           40.033361
# 1               58.632548        10.144612          114.775746
# 2               56.432554         0.583494          114.775746
# 3               48.539365         5.326532          114.775746
# 4               49.379748         0.255712          114.775746
#
#    preferred_spend_line  total_cards  preferred_bal_line  preavgremit1_3_all  \
# 0             10.000000            2           10.000000            1.212784
# 1              5.666667            1            7.600000            1.004907
# 2              6.000000            1            6.000000            1.157115
# 3             11.900945            3           12.720950            2.350858
# 4             13.333333            1           13.333333            1.171551
#
#    Supplementary Cards  isChargeCust         CMV
# 0                    1             0   48.099828
# 1                    0             0  104.018933
# 2                    1             1  120.586919
# 3                    0             1  168.592083
# 4                    0             1  109.204819

# %%
train_2_mean_rem.columns
# Out:
# Index(['FICO', 'Business Revenue', 'Last 6M Avg Util', 'Income',
#        'Last 6M Avg Bal', 'Lending AR% in last 6M', 'ExternalBalance',
#        'Months in Business', 'preferred_spend_line', 'total_cards',
#        'preferred_bal_line', 'preavgremit1_3_all', 'Supplementary Cards',
#        'isChargeCust', 'CMV', 'Assigned Line'],
#       dtype='object')

# %%
cols_x = ['FICO', 'Business Revenue', 'Last 6M Avg Util', 'Income',
       'Last 6M Avg Bal', 'Lending AR% in last 6M', 'ExternalBalance',
       'Months in Business', 'preferred_spend_line', 'total_cards',
       'preferred_bal_line', 'preavgremit1_3_all', 'Supplementary Cards',
       'isChargeCust', 'CMV']

cols_y = ['Assigned Line']

# %%
train_x, test_x, train_y, test_y = train_test_split(train_2_mean_rem[cols_x], train_2_mean_rem[cols_y],
                                                        train_size=0.7,random_state=1)

# %%
#tuning n estimators

n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200]

for estimator in n_estimators:
    clf = RandomForestClassifier(n_estimators=estimator)
    clf.fit(train_x, train_y)
    predictions = clf.predict(test_x)
    print(estimator)
    print("\n")
    print("Train Accuracy :: ", accuracy_score(train_y, clf.predict(train_x)))
    print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
    print("\n\n")
# Out:
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 1
#
#
# Train Accuracy ::  0.804453781512605
# Test Accuracy  ::  0.4568627450980392
#
#
#
# 2
#
#
# Train Accuracy ::  0.8047058823529412
# Test Accuracy  ::  0.46872549019607845
#
#
#
# 4
#
#
# Train Accuracy ::  0.9128571428571428
# Test Accuracy  ::  0.4949019607843137
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 8
#
#
# Train Accuracy ::  0.9729411764705882
# Test Accuracy  ::  0.5217647058823529
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 16
#
#
# Train Accuracy ::  0.9952521008403361
# Test Accuracy  ::  0.5469607843137255
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 32
#
#
# Train Accuracy ::  0.9994957983193278
# Test Accuracy  ::  0.5516666666666666
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 64
#
#
# Train Accuracy ::  0.9999579831932773
# Test Accuracy  ::  0.5618627450980392
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 100
#
#
# Train Accuracy ::  1.0
# Test Accuracy  ::  0.5662745098039216
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys
# 200
#
#
# Train Accuracy ::  1.0
# Test Accuracy  ::  0.5664705882352942

# %%
max_depths = np.linspace(1, 32, 32, endpoint=True)
for max_depth in max_depths:
    clf = RandomForestClassifier(max_depth=max_depth)
    clf.fit(train_x, train_y)
    predictions = clf.predict(test_x)
    print(max_depth)
    print("\n")
    print("Train Accuracy :: ", accuracy_score(train_y, clf.predict(train_x)))
    print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
    print("\n\n")
# Out:
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 1.0
#
#
# Train Accuracy ::  0.5415126050420168
# Test Accuracy  ::  0.5340196078431373
#
#
#
# 2.0
#
#
# Train Accuracy ::  0.5415126050420168
# Test Accuracy  ::  0.5340196078431373
#
#
#
# 3.0
#
#
# Train Accuracy ::  0.5426470588235294
# Test Accuracy  ::  0.5342156862745098
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 4.0
#
#
# Train Accuracy ::  0.5507142857142857
# Test Accuracy  ::  0.5397058823529411
#
#
#
# 5.0
#
#
# Train Accuracy ::  0.5694117647058824
# Test Accuracy  ::  0.5583333333333333
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 6.0
#
#
# Train Accuracy ::  0.5758823529411765
# Test Accuracy  ::  0.5585294117647058
#
#
#
# 7.0
#
#
# Train Accuracy ::  0.5873949579831933
# Test Accuracy  ::  0.5636274509803921
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 8.0
#
#
# Train Accuracy ::  0.5933613445378151
# Test Accuracy  ::  0.5614705882352942
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 9.0
#
#
# Train Accuracy ::  0.6102941176470589
# Test Accuracy  ::  0.5657843137254902
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 10.0
#
#
# Train Accuracy ::  0.6323529411764706
# Test Accuracy  ::  0.5637254901960784
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 11.0
#
#
# Train Accuracy ::  0.6635294117647059
# Test Accuracy  ::  0.5620588235294117
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 12.0
#
#
# Train Accuracy ::  0.6793697478991597
# Test Accuracy  ::  0.5624509803921569
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 13.0
#
#
# Train Accuracy ::  0.719327731092437
# Test Accuracy  ::  0.556078431372549
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 14.0
#
#
# Train Accuracy ::  0.752436974789916
# Test Accuracy  ::  0.5549019607843138
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 15.0
#
#
# Train Accuracy ::  0.7808823529411765
# Test Accuracy  ::  0.551078431372549
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 16.0
#
#
# Train Accuracy ::  0.8179411764705883
# Test Accuracy  ::  0.5518627450980392
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 17.0
#
#
# Train Accuracy ::  0.8573949579831933
# Test Accuracy  ::  0.543235294117647
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 18.0
#
#
# Train Accuracy ::  0.879453781512605
# Test Accuracy  ::  0.55
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 19.0
#
#
# Train Accuracy ::  0.8928571428571429
# Test Accuracy  ::  0.5412745098039216
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 20.0
#
#
# Train Accuracy ::  0.9212184873949579
# Test Accuracy  ::  0.5393137254901961
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 21.0
#
#
# Train Accuracy ::  0.9364705882352942
# Test Accuracy  ::  0.5319607843137255
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 22.0
#
#
# Train Accuracy ::  0.9436974789915966
# Test Accuracy  ::  0.5351960784313725
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 23.0
#
#
# Train Accuracy ::  0.9539495798319327
# Test Accuracy  ::  0.5355882352941177
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 24.0
#
#
# Train Accuracy ::  0.9627310924369747
# Test Accuracy  ::  0.5342156862745098
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 25.0
#
#
# Train Accuracy ::  0.9664285714285714
# Test Accuracy  ::  0.527156862745098
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 26.0
#
#
# Train Accuracy ::  0.970672268907563
# Test Accuracy  ::  0.5293137254901961
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 27.0
#
#
# Train Accuracy ::  0.9771848739495799
# Test Accuracy  ::  0.528235294117647
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 28.0
#
#
# Train Accuracy ::  0.9796218487394958
# Test Accuracy  ::  0.528921568627451
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 29.0
#
#
# Train Accuracy ::  0.9802100840336134
# Test Accuracy  ::  0.5217647058823529
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 30.0
#
#
# Train Accuracy ::  0.9824789915966387
# Test Accuracy  ::  0.5386274509803921
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 31.0
#
#
# Train Accuracy ::  0.9818067226890757
# Test Accuracy  ::  0.5263725490196078
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 32.0
#
#
# Train Accuracy ::  0.9815126050420168
# Test Accuracy  ::  0.5327450980392157

# %%
clf = RandomForestClassifier(max_depth=12,n_estimators=4)
clf.fit(train_x, train_y)
predictions = clf.predict(eval_2_mean_rem)
print("\n")
print("Train Accuracy :: ", accuracy_score(train_y, clf.predict(train_x)))
print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
print("\n\n")
# Out:
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Train Accuracy ::  0.6752521008403362
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-6a9b079bc536> in <module>
#       4 print("\n")
#       5 print("Train Accuracy :: ", accuracy_score(train_y, clf.predict(train_x)))
# ----> 6 print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
#       7 print("\n\n")
#
# ~/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/metrics/classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# ~/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ~/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [10200, 10000]

# %%
def conv_str(df):
    ans = []
    for i in range(len(df)):
        if df[i] == 0:
            ans.append('Low')
        elif df[i] == 1:
            ans.append('Medium')
        else:
            ans.append('High')
    return ans

# %%
ans = conv_str(predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-41a01e6b88de> in <module>
# ----> 1 ans = conv_str(predictions)
#
# NameError: name 'conv_str' is not defined

# %%
ans = pd.DataFrame(ans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-d1134986cf05> in <module>
# ----> 1 ans = pd.DataFrame(ans)
#
# NameError: name 'ans' is not defined

# %%
ans.to_csv('MoreLikeGods_IITKGP_1.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-e5b71e1680d5> in <module>
# ----> 1 ans.to_csv('MoreLikeGods_IITKGP_1.csv')
#
# NameError: name 'ans' is not defined

# %%
MoreLikeGods_IITKGP_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-5af578df9330> in <module>
# ----> 1 MoreLikeGods_IITKGP_1
#
# NameError: name 'MoreLikeGods_IITKGP_1' is not defined

# %%
import xgboost as xgb

# %%
train_2_mean
# Out:
#           ID        FICO  Business Revenue  Last 6M Avg Util     Income  \
# 0          1  828.235294          0.138889        625.911006   1.818182
# 1          2  911.764706          0.027778        611.574748   8.181818
# 2          3  962.352941          0.833333        615.825381   8.181818
# 3          4  892.941177          1.119596        638.076431   9.090909
# 4          1    1.000000          1.000000          1.000000   1.000000
# ...      ...         ...               ...               ...        ...
# 33995  33996  996.470588          0.833333        611.574748   9.090909
# 33996  33997  885.882353          1.119596        617.448254  22.727273
# 33997  33998  976.470588          0.166667        621.613105  18.181818
# 33998  33999  785.882353          0.177233        682.762351  15.290028
# 33999  34000  917.647059          0.138889        650.416923  11.818182
#
#        Last 6M Avg Remit  Last 6M Avg Bal  Lending AR% in last 6M  \
# 0               1.081550       198.113469               58.632548
# 1               1.344479       198.600020               56.497320
# 2               0.720796       197.267767               58.632548
# 3               0.820218       197.355744               58.632548
# 4               1.000000         1.000000                1.000000
# ...                  ...              ...                     ...
# 33995           2.040273       199.590730               56.497320
# 33996           0.943654       197.743579               58.632548
# 33997           0.968569       197.437342               58.632548
# 33998           0.623798       198.254389               58.632548
# 33999           2.640652       201.389811               58.632548
#
#        ExternalBalance  Months in Business  preferred_spend_line  total_cards  \
# 0             0.279273          100.083403              1.000000            1
# 1             5.429062           15.012510             11.679589            1
# 2             0.453212          210.175146             10.000000            1
# 3             5.429062          117.283667             11.679589            1
# 4             1.000000            1.000000              1.000000            1
# ...                ...                 ...                   ...          ...
# 33995         1.837104          250.208507             13.333333            1
# 33996         5.429062            5.004170             11.679589            1
# 33997         1.172531          130.108424              2.000000            1
# 33998         8.072586           18.348624             11.866667            1
# 33999        29.354858          150.125104              5.400000            1
#
#        preferred_bal_line  preavgremit1_3_all  Supplementary Cards  \
# 0                1.000000            1.540594                    1
# 1               12.453257            1.614613                    0
# 2               10.000000            1.044599                    0
# 3               12.453257            1.145729                    1
# 4                1.000000            1.000000                    1
# ...                   ...                 ...                  ...
# 33995           13.333333            1.913514                    1
# 33996           12.453257            1.014169                    0
# 33997           12.666667            1.228365                    0
# 33998           11.866667            0.976599                    0
# 33999           10.000000            2.319554                    1
#
#        isChargeCust         CMV  Assigned Line
# 0                 0  100.104991              0
# 1                 1  146.654045              2
# 2                 0   98.249570              1
# 3                 0  140.862306              0
# 4                 1    1.000000              1
# ...             ...         ...            ...
# 33995             1  155.080895              0
# 33996             0  162.972461              1
# 33997             0  108.767642              0
# 33998             0  101.471601              0
# 33999             0   52.588640              2
#
# [34000 rows x 18 columns]

# %%
cols_x = ['FICO', 'Business Revenue', 'Last 6M Avg Util', 'Income',
       'Last 6M Avg Remit', 'Last 6M Avg Bal', 'Lending AR% in last 6M',
       'ExternalBalance', 'Months in Business', 'preferred_spend_line',
       'total_cards', 'preferred_bal_line', 'preavgremit1_3_all',
       'Supplementary Cards', 'isChargeCust', 'CMV']
cols_y = ['Assigned Line']

# %%
train_x, test_x, train_y, test_y = train_test_split(train_2_mean[cols_x], train_2_mean[cols_y],
                                                        train_size=0.7,random_state=1)

# %%
model = xgb.XGBClassifier()
model.fit(train_x, train_y)
# Out:
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/jakher/anaconda3/envs/tf_gpu/lib/python3.7/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
print(model)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
y_pred = model.predict(test_x)
predictions = [round(value) for value in y_pred]

# %%
accuracy = accuracy_score(test_y, predictions)

# %%
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 57.08%

# %%
print("Train Accuracy :: ", accuracy_score(train_y, model.predict(train_x)))
print("Test Accuracy  :: ", accuracy_score(test_y, predictions))
# Out:
# Train Accuracy ::  0.5919747899159664
# Test Accuracy  ::  0.5707843137254902

# %%
# !conda install -c conda-forge featuretools
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /home/jakher/anaconda3/envs/tf_gpu:
#
# The following NEW packages will be INSTALLED:
#
#     bokeh:            1.3.4-py37_0         conda-forge
#     click:            7.0-py_0             conda-forge
#     dask:             2.4.0-py_0           conda-forge
#     distributed:      2.5.1-py_0           conda-forge
#     featuretools:     0.11.0-py_0          conda-forge
#     fsspec:           0.5.1-py_0           conda-forge
#     funcsigs:         1.0.2-py_3           conda-forge
#     heapdict:         1.0.1-py_0           conda-forge
#     locket:           0.2.0-py_2           conda-forge
#     msgpack-python:   0.6.2-py37hc9558a2_0 conda-forge
#     packaging:        19.2-py_0            conda-forge
#     partd:            1.0.0-py_0           conda-forge
#     pathlib:          1.0.1-py_1           conda-forge
#     s3fs:             0.3.4-py_0           conda-forge
#     sortedcontainers: 2.1.0-py_0           conda-forge
#     tblib:            1.4.0-py_0           conda-forge
#     tqdm:             4.36.1-py_0          conda-forge
#     zict:             1.0.0-py_0           conda-forge
#
# The following packages will be UPDATED:
#
#     _r-mutex:         1.0.0-anacondar_1                --> 1.0.1-anacondar_1 conda-forge
#
# Proceed ([y]/n)? ^C

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined
